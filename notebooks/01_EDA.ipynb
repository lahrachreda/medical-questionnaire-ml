# %% [markdown]
# ## Analyse de Data

# %% [markdown]
# ### Problématique
# L'impact de jeux vidéo sur la cohérence  familiale (l'objectif de questionnaire)

# %% [markdown]
# ### chargement de data

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/Questionnaire.csv", sep=";",encoding="latin1")

# %% [markdown]
# ### Compréhension du data

# %% [markdown]
# #### Un échantillon de data

# %%
df.head(10)
# Out:
#     Âge :     Genre :     Situation familiale :     Nombre d'enfants :    \
# 0     18-24       Homme      Marié(e) / En couple                      2
# 1     45-54       Homme      Marié(e) / En couple                      3
# 2     25-34       Femme      Marié(e) / En couple                  Aucun
# 3     25-34       Femme      Marié(e) / En couple                      2
# 4     35-44       Femme      Marié(e) / En couple                      2
# 5     35-44       Femme      Marié(e) / En couple                      3
# 6     45-54       Homme      Marié(e) / En couple              4 et plus
# 7     35-44       Femme      Marié(e) / En couple                      2
# 8     45-54       Homme      Marié(e) / En couple              4 et plus
# 9     25-34       Homme               Célibataire                  Aucun
#
#     Niveau d'études :     Jouez vous aux jeux vidéo ?    \
# 0       Master (Bac +5)                             Oui
# ...

# %% [markdown]
# ### Métadonnée de data

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 17 columns):
#  #   Column                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                     --------------  -----
#  0     Âge :                                                                                                    90 non-null     str
#  1     Genre :                                                                                                  90 non-null     str
#  2     Situation familiale :                                                                                    90 non-null     str
#  3     Nombre d'enfants :                                                                                       90 non-null     str
# ...

# %% [markdown]
# #### Récapulatif statistique

# %%
df.describe()
# Out:
#          Âge :     Genre :     Situation familiale :     Nombre d'enfants :    \
# count         90          90                        90                     90
# unique         5           2                         2                      5
# top        18-24       Homme               Célibataire                  Aucun
# freq          39          46                        50                     55
#
#          Niveau d'études :     Jouez vous aux jeux vidéo ?    \
# count                     90                              90
# unique                     6                               2
# top          Master (Bac +5)                             Oui
# freq                      28                              55
#
#          Fréquence de jeu (par semaine) :    \
# count                                    89
# unique                                    5
# top                        Moins de 1 heure
# freq                                     42
#
# ...

# %% [markdown]
# #### Analyse de la qualité des données
# ##### pour cela je developpe un  script devra être capable de détecter les anomalies automatiquement :

# %% [markdown]
# ##### # Configuration du chemin du projet (Project Root)

# %%
import sys
from pathlib import Path

# Dossier racine du projet
PROJECT_ROOT = Path().resolve().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
print(sys.path[:3])
# Out:
# /home/reda/medical-questionnaire-ml
# ['/home/reda/medical-questionnaire-ml', '/usr/lib/python312.zip', '/usr/lib/python3.12']

# %% [markdown]
# ##### # Rapport synthétique

# %%
from ml.anomaly_detection import AnomalyDetector
detector = AnomalyDetector(df)
detector.run()
# Out:
# ...
#              RAPPORT DE DÉTECTION DES ANOMALIES
# ...
#
# Informations générales
# -----------------------------------------------------------------
# Nombre d'observations : 90
# Nombre de variables   : 17
#
# Qualité des données
# -----------------------------------------------------------------
# Doublons               : 0
# Colonnes constantes    : 0
# Variables catégorielles: 17
# Variables numériques   : 0
#
# Valeurs manquantes
# -----------------------------------------------------------------
# Colonnes concernées : 3
#
#   Fréquence de jeu (par semaine) :                   1 (1.1 %)
#   Fréquence de jeu de vos enfants (par semaine) :    30 (33.3 %)
# Où vos enfants jouent-ils habituellement aux jeux vidéo ? (Sélection multiple possible)    29 (32.2 %)
#
# Conclusion
# -----------------------------------------------------------------
# Le jeu de données présente une bonne qualité globale.
# Les principales anomalies concernent les valeurs manquantes.
# ...

# %% [markdown]
# ### Conclusions de l'analyse :
# #### À l'issue de l'analyse exploratoire, plusieurs constats ont été établis :
# - certaines variables ne sont pas standardisées et nécessitent une harmonisation
# - certaines colonnes contiennent des données sous des formats hétérogènes (catégoriels et numériques), ce qui nécessitera un prétraitement adapté avant leur exploitation.

# %% [markdown]
# ### Décision
#
# Ces observations montrent que le jeu de données nécessite une étape de prétraitement avant toute modélisation. La prochaine phase consistera à standardiser les variables, traiter les valeurs manquantes et préparer les données pour les algorithmes de Machine Learning.
